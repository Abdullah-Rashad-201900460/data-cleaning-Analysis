# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy import stats

# %%
data = pd.read_csv("E:/MPOB_data1.csv")

# %%
data.head(10)
# Out:
#    Year Month  CrudePalmOil   SoyabeanOil   GroundnutOil   SunflowerOil   \
# 0  2006   Jan          424.0         532.0          930.0          591.0
# 1  2006   Feb          445.0         535.0          921.0          595.0
# 2  2006   Mar          440.0         539.0          902.0          606.0
# 3  2006   Apr          439.0         540.0          899.0          659.0
# 4  2006   May          440.0         588.0          892.0          679.0
# 5  2006   Jun          437.0         601.0          824.0          666.0
# 6  2006   Jul          471.0         630.0          928.0          647.0
# 7  2006   Aug          510.0         629.0          944.0          666.0
# 8  2006   Sep          497.0         602.0          965.0          670.0
# 9  2006   Oct          507.0         615.0         1068.0          666.0
#
#    RapeseedOil   CoconutOil   FishOil   Tallow   Lard
# 0         733.0        569.0     750.0    445.0  407.0
# 1         723.0        591.0     761.0    430.0  405.0
# ...

# %%
data.describe()
# Out:
#               Year  CrudePalmOil   SoyabeanOil   GroundnutOil   SunflowerOil   \
# count   156.000000     153.000000    153.000000     153.000000     153.000000
# mean   2012.000000     792.725490    947.856209    1414.601307     988.843137
# std       3.753708     205.275336    229.628287     515.906259     314.525292
# min    2006.000000     424.000000    532.000000       0.000000       0.000000
# 25%    2009.000000     663.000000    790.000000    1214.000000     802.000000
# 50%    2012.000000     771.000000    883.000000    1356.000000     887.000000
# 75%    2015.000000     906.000000   1140.000000    1673.000000    1221.000000
# max    2018.000000    1292.000000   1537.000000    2555.000000    2045.000000
#
#        RapeseedOil   CoconutOil      FishOil       Tallow         Lard
# count    153.000000   153.000000   153.000000   153.000000   153.000000
# mean     992.202614  1149.137255  1482.954248   853.215686   792.594771
# ...

# %%
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 156 rows and 11 columns

# %%
#display sorted mean for all numeric colomns 
data.mean().sort_values(ascending=False)[1:]
# Out:
# C:\Users\NUN\AppData\Local\Temp\ipykernel_15668\3919038723.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean().sort_values(ascending=False)[1:]
# FishOil          1482.954248
# GroundnutOil     1414.601307
# CoconutOil       1149.137255
# RapeseedOil       992.202614
# SunflowerOil      988.843137
# SoyabeanOil       947.856209
# Tallow            853.215686
# CrudePalmOil      792.725490
# Lard              792.594771
# dtype: float64

# %%
#configration the plot 
fig , ax =plt.subplots(figsize = (12,8))
plt.xticks(rotation=70)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.bar("FishOil",data["FishOil "],width=0.5)
plt.bar("GroundnutOil",data["GroundnutOil "],width=0.5)
plt.bar("CoconutOil",data["CoconutOil "],width=0.5)
plt.bar("RapeseedOil",data["RapeseedOil "],width=0.5) 
plt.bar("SunflowerOil",data["SunflowerOil "],width=0.5)
plt.title("oil prices from 2006 to 2008")
plt.xlabel("oil")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
#get max value 
max_val = data["GroundnutOil "].max()
max_val
# Out:
# 2555.0

# %%
data[:][data["GroundnutOil "]== max_val]
# Out:
#     Year Month  CrudePalmOil   SoyabeanOil   GroundnutOil   SunflowerOil   \
# 76  2012   May         1085.0        1218.0         2555.0         1275.0
#
#     RapeseedOil   CoconutOil   FishOil   Tallow    Lard
# 76        1235.0       1155.0    1758.0   1223.0  1045.0

# %%
#get min value 
min_val = data["GroundnutOil "].min()
data[:][data["GroundnutOil "]== min_val]
# Out:
#     Year Month  CrudePalmOil   SoyabeanOil   GroundnutOil   SunflowerOil   \
# 29  2008   Jun         1213.0        1537.0            0.0         2045.0
# 67  2011   Aug         1083.0        1330.0            0.0         1327.0
# 68  2011   Sep         1068.0        1309.0            0.0            0.0
# 69  2011   Oct          994.0        1220.0            0.0            0.0
# 71  2011   Dec         1026.0        1203.0            0.0         1189.0
# 72  2012   Jan         1061.0        1218.0            0.0         1208.0
# 73  2012   Feb         1106.0        1255.0            0.0         1249.0
# 74  2012   Mar         1152.0        1287.0            0.0         1265.0
# 75  2012   Apr         1181.0        1310.0            0.0         1324.0
#
#     RapeseedOil   CoconutOil   FishOil   Tallow    Lard
# 29        1577.0       1551.0    1808.0   1118.0  1237.0
# 67        1363.0       1454.0    1542.0   1270.0  1238.0
# 68        1316.0       1310.0    1605.0   1220.0  1193.0
# ...

# %%
mean=data["GroundnutOil "].mean()
mean
# Out:
# 1414.6013071895425

# %%
median=data["GroundnutOil "].median()
median
# Out:
# 1356.0

# %%
plt.scatter(data["Year"],data["GroundnutOil "],color='blue')
plt.axhline(min_val , label="Minmum",color="red") 
plt.axhline(max_val , label="Maxmum",color="red") 
plt.axhline(mean , label="Mean",color="yellow")
plt.axhline(median , label="Median",color="green")  
plt.legend(loc="upper right")
plt.title("GroundnutOil Prices 2006 to 2008")
plt.xlabel("Year")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
data.dropna(axis=0,inplace=True)

# %%
selected_data=data[["FishOil ","GroundnutOil "]]

# %%
selected_data.boxplot()
# Out:
# <AxesSubplot: >

# %%
data.boxplot(column="Lard ",by="Year")
# Out:
# <AxesSubplot: title={'center': 'Lard '}, xlabel='Year'>

# %%
colomns= data.columns[2:].values
colomns
# Out:
# array(['CrudePalmOil ', 'SoyabeanOil ', 'GroundnutOil ', 'SunflowerOil ',
#        'RapeseedOil ', 'CoconutOil ', 'FishOil ', 'Tallow ', 'Lard '],
#       dtype=object)

# %%
data_array=data.iloc[:,2:].values
data_array
# Out:
# array([[ 424.,  532.,  930., ...,  750.,  445.,  407.],
#        [ 445.,  535.,  921., ...,  761.,  430.,  405.],
#        [ 440.,  539.,  902., ...,  807.,  410.,  431.],
#        ...,
#        [ 590.,  775., 1289., ..., 1325.,  735.,  598.],
#        [ 561.,  766., 1281., ..., 1355.,  780.,  607.],
#        [ 551.,  757., 1265., ..., 1400.,  730.,  679.]])

# %%
bp=plt.boxplot(data_array,showcaps=True,showfliers=True)
plt.xticks([1,2,3,4,5,6,7,8,9],colomns)
plt.title("oil production 2006 - 2008")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()

# %%
bp=plt.violinplot(data_array,showmedians=True)
plt.xticks([1,2,3,4,5,6,7,8,9],colomns)
plt.title("oil production 2006 - 2008")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()

# %%
data[["FishOil ","Month"]].groupby("Month").mean()
# Out:
#           FishOil
# Month
# Apr    1481.692308
# Aug    1473.307692
# Dec    1537.083333
# Feb    1511.538462
# Jan    1508.307692
# Jul    1453.923077
# Jun    1433.923077
# Mar    1507.230769
# May    1474.384615
# Nov    1511.833333
# Oct    1437.666667
# Sep    1467.461538

# %%
n , bins, patches=plt.hist(data["FishOil "],facecolor = "gray",edgecolor = "blue", bins=20)
plt.xlabel("prices")
plt.ylabel("counts")
plt.show()

# %%
n , bins, patches=plt.hist(data["FishOil "],cumulative=True,facecolor = "gray",edgecolor = "blue", bins=20)
plt.xlabel("prices")
plt.ylabel("counts")
plt.show()

# %%
n , bins, patches=plt.hist(data["FishOil "],label="FishOil",facecolor = "gray",edgecolor = "blue", bins=20)
n , bins, patches=plt.hist(data["GroundnutOil "],label="GroundnutOil",alpha=0.6,facecolor = "green",edgecolor = "black", bins=20)

plt.xlabel("prices")
plt.ylabel("counts")
plt.legend()
plt.show()

# %%
grouped_data=data[["FishOil ","Month"]].groupby("Month",as_index=False).sum()
grouped_data
# Out:
#    Month  FishOil
# 0    Apr   19262.0
# 1    Aug   19153.0
# 2    Dec   18445.0
# 3    Feb   19650.0
# 4    Jan   19608.0
# 5    Jul   18901.0
# 6    Jun   18641.0
# 7    Mar   19594.0
# 8    May   19167.0
# 9    Nov   18142.0
# 10   Oct   17252.0
# 11   Sep   19077.0

# %%
plt.pie(grouped_data["FishOil "],labels=grouped_data["Month"],autopct='%.1f')
